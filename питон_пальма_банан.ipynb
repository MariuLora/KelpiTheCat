# %% [markdown]
# <a href="https://colab.research.google.com/github/MariuLora/KelpiTheCat/blob/main/%D0%BF%D0%B8%D1%82%D0%BE%D0%BD_%D0%BF%D0%B0%D0%BB%D1%8C%D0%BC%D0%B0_%D0%B1%D0%B0%D0%BD%D0%B0%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#общая инфа переменные и тд

#обновляющийся словарь в процессе игры, мы в него записываем наши заметки и можем их простматривать в течении игры
diary = {}

#перманентный словарь, секретный документ
book = {}

#инвентарь
inventory = [diary]

#инструмент, его наличие влияет на сюжет (функционнальный молоток-лом)
tool = False

#отношения с крысой, максимум 4
love = 0

#наличие карты
card = False

# %%
#спасательный отсек
print("Ты приходишь в себя.")
print("Ты находишь")

# %%
#мини склад
print("Дверь откроется. Мы в коридоре")
print("Мини склад открыт мы заходим")
print("Выберите цифру:")
print("1. Посмотреть продовольственные продукты")
print("2. Посмотреть инструменты:")

# %%
#коридор

# %%
#топливный и машинный отдел

# %%
#пункт управления

# %%
#библиотека

# %%
#концовка1 убийство крысы

# %%
#концовка2 крыса спасает человечество с помощью крови

# %%
#концовка3 летим умирать

# %%
#концовка4 улетаем в шведскую семью
if love == 2:
  if tool == True:
    print("Есть инструмент-Мы улетаем жить с крысой в семью")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1629400737.py in <cell line: 0>()
#       1 #концовка4 улетаем в шведскую семью
# ----> 2 if love == 2:
#       3   if tool == True:
#       4     print("Есть инструмент-Мы улетаем жить с крысой в семью")
#
# NameError: name 'love' is not defined
